# %% [markdown]
# ## Text Mining Project

# %% [markdown]
# ### Building transcripts for modern family

# %%
# reading txt file
temp = open('Transcripts/MFs1.txt','r').read().splitlines()

# %%
len(temp)
# Out:
# 11645

# %%
# setting main characters name list

characters = ['Claire', 'Phil', 'Haley', 'Luke', 'Alex', 'Gloria', 
              'Jay', 'Manny', 'Mitchell', 'Cameron', 'Lily',
             'Claire :', 'Phil :', 'Haley :', 'Luke :', 'Alex :', 'Gloria :', 
              'Jay :', 'Manny :', 'Mitchell :', 'Cameron :', 'Lily :', 'Cam', 'Cam :']

# %% [markdown]
# ## Season 1

# %%
# Getting rid of the empty str

for line in temp:
    if line == '':
        temp.remove(line)

# %%
# Merging str with less than 2 words to the previous sent
for line in enumerate(temp):
    if len(line[1].split()) < 2:
        temp[line[0]-1] = temp[line[0]-1] + ' ' + line[1]

# %%
# Getting rid of the str with less than 2
new_temp = []
for line in temp:
    if len(line.split()) > 2:
        new_temp.append(line)
        
new_temp
# Out:
# ['Claire : Kids, breakfast! Kids? Phil, would you get them?',
#  'Phil : Yeah, just a sec.',
#  'Claire : Kids!',
#  'Phil : That is so,..',
#  'Claire : Okay...',
#  'Phil : Kids, get down here!',
#  "Haley : Why are you guys yelling at us, when we're way upstairs,",
#  'just text me.',
#  "Claire : Alright, That's not gonna happen, and, wow, you're not",
#  'wearing that outfit.',
#  "Haley : What's Wrong with it?",
#  'Claire : Honey, do you have anything to say to your daughter...',
#  'about her skirt?',
#  'Phil : Sorry? Oh yeah, that looks really cute sweetheart!',
#  'Haley : Thanks!',
#  "Claire : No, it's way to short, people know you're a girl, you don't",
#  'need to prove it to them.',
#  'Alex : Luke got his head stuck in the banister again.',
#  "Phil : I got it. Where's the baby oil?",
#  "Claire : It's on our bedside tip... I Don't know, find it. Come on!",
#  'Claire : I... was out of control growing up, there, you know, i said',
# ...

# %%
# Removing irrelevant characters txt

for line in new_temp:
    if (":" in line.split()) and (line.split()[0] not in characters):
        new_temp.remove(line)

# %%
len(new_temp)
# Out:
# 9588

# %%
new_temp
# Out:
# ['Claire : Kids, breakfast! Kids? Phil, would you get them?',
#  'Phil : Yeah, just a sec.',
#  'Claire : Kids!',
#  'Phil : That is so,..',
#  'Claire : Okay...',
#  'Phil : Kids, get down here!',
#  "Haley : Why are you guys yelling at us, when we're way upstairs,",
#  'just text me.',
#  "Claire : Alright, That's not gonna happen, and, wow, you're not",
#  'wearing that outfit.',
#  "Haley : What's Wrong with it?",
#  'Claire : Honey, do you have anything to say to your daughter...',
#  'about her skirt?',
#  'Phil : Sorry? Oh yeah, that looks really cute sweetheart!',
#  'Haley : Thanks!',
#  "Claire : No, it's way to short, people know you're a girl, you don't",
#  'need to prove it to them.',
#  'Alex : Luke got his head stuck in the banister again.',
#  "Phil : I got it. Where's the baby oil?",
#  "Claire : It's on our bedside tip... I Don't know, find it. Come on!",
#  'Claire : I... was out of control growing up, there, you know, i said',
# ...

# %%
for line in enumerate(new_temp): 
    if line[1].split()[0] not in characters:
        new_temp[line[0]-1] = new_temp[line[0]-1] + ' ' + line[1]
        new_temp.remove(line[1])

# %%
len(new_temp)
# Out:
# 7335

# %%
Phil = []
Claire = []
Haley = []
Alex = []
Luke = []
Gloria = []
Manny = []
Jay = []
Cam = []
Mitchell = []
Lily = []

# %%
new_temp[2].split()[0]
# Out:
# 'Claire'

# %%
for line in new_temp:
    if line.split()[1] == ":":
        if line.split()[0] == 'Phil':
            Phil.append(line)
        elif line.split()[0] == 'Claire':
            Claire.append(line)
        elif line.split()[0] == 'Haley':
            Haley.append(line)
        elif line.split()[0] == 'Alex':
            Alex.append(line)
        elif line.split()[0] == 'Luke':
            Luke.append(line)
        elif line.split()[0] == 'Gloria':
            Gloria.append(line)
        elif line.split()[0] == 'Manny':
            Manny.append(line)
        elif line.split()[0] == 'Jay':
            Jay.append(line)
        elif line.split()[0] == 'Cameron':
            Cam.append(line)
        elif line.split()[0] == 'Mitchell':
            Mitchell.append(line)
        elif line.split()[0] == 'Lily':
            Lily.append(line)

# %%
dict1 = {
    'Phil': Phil,
    'Claire' : Claire,
    'Haley' : Haley,
    'Alex' : Alex,
    'Luke' : Luke,
    'Gloria' : Gloria,
    'Jay' : Jay,
    'Manny' : Manny,
    'Cam' : Cam, 
    'Mitch' : Mitchell,
    'Lily' : Lily
}

# %%
import pandas as pd
df = pd.DataFrame.from_dict(dict1, orient='index')
df
# Out:
#                                                      0     \
# Phil                             Phil : Yeah, just a sec.
# Claire  Claire : Kids, breakfast! Kids? Phil, would yo...
# Haley   Haley : Why are you guys yelling at us, when w...
# Alex    Alex : Luke got his head stuck in the banister...
# Luke          Luke : I thought I could get out this time.
# Gloria  Gloria : Bravo Manny! Kick it! Kick it! Manny ...
# Jay     Jay : Gloria, there Owen's six, Let's take it ...
# Manny   Manny : I'm quitting soccer, it is a game for ...
# Cam     Cameron : Sorry, sorry, sorry, Daddy needed sn...
# Mitch         Mitchell : Who's the good girl? Who's that?
# Lily                                        Lily : Mommy!
#
#                                                      1     \
# Phil                                 Phil : That is so,..
# Claire                                     Claire : Kids!
# Haley                       Haley : What's Wrong with it?
# ...

# %%
df.to_csv('MFs1.csv')

# %% [markdown]
# ## Season 2

# %%
s2 = open('Transcripts/MFs2.txt','r').read().splitlines()

# %%
s2
# Out:
# ['Modern Family',
#  '2x01 : The Old Wagon',
#  'Claire : Honey, do you need me to move the car?',
#  "Phil : Ho, no! It's nothing. I'm alright. Oh no! Iron cross",
#  'Claire : Oh God... Phil... You okay?',
#  'Phil : Yes. I am. I am okay.',
#  'Claire : Honey, why do we keep this car?',
#  "Phil : It's a classic!",
#  "Claire : No, it just sits here. And the seatbelts don't work. The",
#  "doors stick. It leaks fluids. We haven't put fluids in it in 10 years.",
#  "Phil : Well, I'm gonna fix all that anyway. And then, uh, it's gonna",
#  "be Haley's car.",
#  "Claire : Oh, we're not giving this car to Haley. It's way too easy to",
#  'fit a mattress in the back.',
#  'Phil : Remember?',
#  "Claire : Oh, no. We're selling it.",
#  'Phil : What?!',
#  '',
#  '[OPENING CREDITS]',
#  'Cameron : "while the spray-tanned starlet claims to be six weeks',
#  'sober, sources down under say she has been bar-hopping like a',
#  'coked-up kangaroo."',
# ...

# %%
# Getting rid of the empty str

for line in s2:
    if line == '':
        s2.remove(line)

# %%
# Merging str with less than 2 words to the previous sent
for line in enumerate(s2):
    if len(line[1].split()) < 2:
        s2[line[0]-1] = s2[line[0]-1] + ' ' + line[1]

# %%
# Getting rid of the str with less than 2
new_s2 = []
for line in s2:
    if len(line.split()) > 2:
        new_s2.append(line)

# %%
# Removing irrelevant characters txt

for line in new_s2:
    if (":" in line.split()) and (line.split()[0] not in characters):
        new_s2.remove(line)

# %%
len(new_s2)
# Out:
# 10067

# %%
for line in enumerate(new_s2): 
    if line[1].split()[0] not in characters:
        new_s2[line[0]-1] = new_s2[line[0]-1] + ' ' + line[1]
        new_s2.remove(line[1])

# %%
Phil2 = []
Claire2 = []
Haley2 = []
Alex2 = []
Luke2 = []
Gloria2 = []
Manny2 = []
Jay2 = []
Cam2 = []
Mitchell2 = []
Lily2 = []

# %%
for line in new_s2:
    if line.split()[1] == ":":
        if line.split()[0] == 'Phil':
            Phil2.append(line)
        elif line.split()[0] == 'Claire':
            Claire2.append(line)
        elif line.split()[0] == 'Haley':
            Haley2.append(line)
        elif line.split()[0] == 'Alex':
            Alex2.append(line)
        elif line.split()[0] == 'Luke':
            Luke2.append(line)
        elif line.split()[0] == 'Gloria':
            Gloria2.append(line)
        elif line.split()[0] == 'Manny':
            Manny2.append(line)
        elif line.split()[0] == 'Jay':
            Jay2.append(line)
        elif line.split()[0] == 'Cameron':
            Cam2.append(line)
        elif line.split()[0] == 'Mitchell':
            Mitchell2.append(line)
        elif line.split()[0] == 'Lily':
            Lily2.append(line)

# %%
dict2 = {
    'Phil': Phil2,
    'Claire' : Claire2,
    'Haley' : Haley2,
    'Alex' : Alex2,
    'Luke' : Luke2,
    'Gloria' : Gloria2,
    'Jay' : Jay2,
    'Manny' : Manny2,
    'Cam' : Cam2, 
    'Mitch' : Mitchell2,
    'Lily' : Lily2
}

# %%
import pandas as pd
df2 = pd.DataFrame.from_dict(dict2, orient='index')
df2

# %%
df2.to_csv('MFs2.csv')

# %% [markdown]
# ## trying

# %%
Phil

# %%
phil_word = []
for sent in Phil:
    for word in sent.split()[2:]:
        phil_word.append(word)

# %%
phil_word

# %% [markdown]
# *Visualisations*

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
import seaborn as sns

# %% [markdown]
# Opening both dictionaries that contain all the words said by each character and all words said per season respectively. The keys of this dictionary are lists of words.

# %%
with open('Dictionaries/dict_char.pkl','rb') as handle:
    b = pickle.load(handle)
    
with open('Dictionaries/dict_season.pkl','rb') as handle2:
    c = pickle.load(handle2)
    
#b
print(b.keys)
#c
print(c.keys())
# Out:
# dict_keys(['phil', 'claire', 'luke', 'haley', 'alex', 'gloria', 'jay', 'manny', 'mitch', 'cam', 'lily'])
# dict_keys(['season1', 'season2', 'season3', 'season5'])

# %% [markdown]
# Most common words for seasons 1, 2, 3 and 5 combined

# %%
# Concatenate lists of words spoken in a given season to one another
all_seasons = c['season1'] + c['season2'] + c['season3'] + c['season5']

all_s_count = (word for word in all_seasons)

all_seasons_words = Counter(all_s_count)
#all_seasons_words.most_common(200)

# %%
# Bar Charts

# %% [markdown]
# Bar Chart of most active characters by words spoken

# %% [markdown]
# Preparing dictionaries for bar chart generation

# %%
#sorted(all_seasons_words)
bar_chart_dict = dict(sorted(all_seasons_words.items(), key=lambda item: item[1], reverse=1))

#bar_chart_dict
first_15_pairs = {k: bar_chart_dict[k] for k in list(bar_chart_dict)[:15]}
#first_15_pairs

# %% [markdown]
# Initialisation of Graph style using the Seaborn package

# %%
sns.set_style('darkgrid') # darkgrid, white grid, dark, white and ticks
colors = sns.color_palette('deep') # color palette of bars
plt.rc('axes', titlesize=18)     # fontsize of the axes title
plt.rc('axes', labelsize=14)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=12)    # fontsize of the tick labels
plt.rc('ytick', labelsize=12.5)    # fontsize of the tick labels
plt.rc('legend', fontsize=13)    # legend fontsize
plt.rc('font', size=13)          # controls default text sizes

keys = first_15_pairs.keys()
values = first_15_pairs.values()

plt.figure(figsize=(8,4), tight_layout=True)
plt.bar(keys, values, color=colors[:15])
plt.title("15 most common words in Modern Family")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Word Cloud of 50 most common words

# %%
# Word cloud

wordcloud = WordCloud(width = 500, height = 250, max_words=50, mode='RGB', background_color='white').generate_from_frequencies(all_seasons_words)

plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %% [markdown]
# Counting each Character's most common words

# %%
phil_count = (word for word in b['phil']) #Phil's most common words
c = Counter(phil_count)
c.most_common(200)
# Out:
# [('oh', 302),
#  ('know', 273),
#  ('okay', 255),
#  ('hey', 228),
#  ('get', 225),
#  ('yeah', 215),
#  ('like', 213),
#  ('got', 181),
#  ('right', 180),
#  ('go', 172),
#  ('claire', 170),
#  ('one', 144),
#  ('well', 137),
#  ('gon', 136),
#  ('let', 135),
#  ('think', 134),
#  ('family', 129),
#  ('good', 127),
#  ('want', 126),
#  ('really', 122),
#  ('see', 117),
#  ('little', 106),
#  ('time', 103),
#  ('look', 100),
#  ('luke', 98),
#  ('say', 97),
#  ('modern', 96),
#  ('come', 95),
#  ('guy', 95),
#  ('sorry', 94),
#  ('buddy', 93),
#  ('uh', 93),
#  ('season', 89),
#  ('need', 87),
#  ('honey', 86),
#  ('thing', 86),
#  ('way', 83),
#  ('would', 82),
#  ('love', 81),
#  ('great', 77),
#  ('kid', 75),
#  ('back', 74),
#  ('could', 73),
#  ('ca', 72),
#  ('make', 71),
#  ('doe', 65),
#  ('take', 65),
#  ('something', 65),
#  ('two', 63),
#  ('day', 63),
#  ('um', 62),
#  ('fine', 60),
#  ('mom', 60),
#  ('dad', 58),
#  ('never', 58),
#  ('much', 57),
#  ('going', 57),
# ...

# %%
claire_count = (word for word in b['claire'])
q = Counter(claire_count)
q.most_common(200)
# Out:
# [('oh', 496),
#  ('okay', 327),
#  ('know', 284),
#  ('phil', 278),
#  ('honey', 218),
#  ('yeah', 204),
#  ('get', 191),
#  ('gon', 186),
#  ('go', 186),
#  ('right', 183),
#  ('really', 142),
#  ('got', 140),
#  ('luke', 138),
#  ('come', 135),
#  ('like', 135),
#  ('dad', 133),
#  ('well', 131),
#  ('think', 128),
#  ('one', 122),
#  ('god', 118),
#  ('family', 117),
#  ('would', 116),
#  ('want', 115),
#  ('let', 113),
#  ('haley', 112),
#  ('thing', 106),
#  ('little', 102),
#  ('sorry', 95),
#  ('need', 93),
#  ('good', 92),
#  ('yes', 90),
#  ('time', 85),
#  ('say', 83),
#  ('make', 83),
#  ('kid', 82),
#  ('ca', 82),
#  ('could', 82),
#  ('modern', 81),
#  ('mm', 81),
#  ('take', 80),
#  ('thank', 78),
#  ('going', 78),
#  ('season', 77),
#  ('see', 77),
#  ('alex', 76),
#  ('back', 75),
#  ('mm-hmm', 75),
#  ('sweetie', 74),
#  ('stop', 74),
#  ('fine', 72),
#  ('hi', 71),
#  ('hey', 70),
#  ('look', 69),
#  ('day', 68),
#  ('guy', 68),
#  ('way', 66),
#  ('great', 66),
# ...

# %%
luke_count = (word for word in b['luke'])
r = Counter(luke_count)
r.most_common(200)
# Out:
# [('dad', 96),
#  ('mom', 67),
#  ('like', 54),
#  ('yeah', 46),
#  ('oh', 44),
#  ('know', 43),
#  ('go', 39),
#  ('get', 38),
#  ('okay', 38),
#  ('hey', 37),
#  ('one', 35),
#  ('got', 33),
#  ('think', 33),
#  ('gon', 32),
#  ('look', 28),
#  ('could', 27),
#  ('see', 24),
#  ('come', 23),
#  ('really', 23),
#  ('well', 22),
#  ('ca', 22),
#  ('season', 22),
#  ('right', 22),
#  ('family', 21),
#  ('thing', 21),
#  ('good', 20),
#  ('guy', 20),
#  ('modern', 20),
#  ('say', 20),
#  ('want', 19),
#  ('back', 18),
#  ('going', 18),
#  ('said', 17),
#  ('need', 17),
#  ('take', 17),
#  ('mean', 16),
#  ('sorry', 16),
#  ('would', 16),
#  ('doe', 16),
#  ('even', 16),
#  ('time', 15),
#  ('fun', 15),
#  ('grandpa', 15),
#  ('friend', 14),
#  ('awesome', 14),
#  ('manny', 14),
#  ('u', 14),
#  ('thanks', 13),
#  ('cool', 13),
#  ('uncle', 12),
#  ('sure', 12),
#  ('bad', 12),
#  ('thought', 11),
#  ('made', 11),
#  ('ow', 11),
#  ('help', 11),
#  ('never', 11),
#  ('feel', 11),
# ...

# %%
haley_count = (word for word in b['haley'])
haley_words = Counter(haley_count)
haley_words.most_common(200)
# Out:
# [('oh', 124),
#  ('mom', 84),
#  ('know', 82),
#  ('like', 78),
#  ('okay', 68),
#  ('get', 61),
#  ('go', 59),
#  ('yeah', 52),
#  ('dad', 50),
#  ('god', 49),
#  ('hey', 48),
#  ('gon', 48),
#  ('one', 42),
#  ('dylan', 41),
#  ('got', 39),
#  ('family', 39),
#  ('think', 39),
#  ('well', 36),
#  ('ca', 36),
#  ('uh', 33),
#  ('would', 33),
#  ('look', 33),
#  ('really', 32),
#  ('right', 32),
#  ('want', 30),
#  ('modern', 30),
#  ('let', 29),
#  ('season', 27),
#  ('back', 27),
#  ('time', 26),
#  ('guy', 25),
#  ('come', 25),
#  ('could', 25),
#  ('good', 24),
#  ('even', 24),
#  ('never', 24),
#  ('see', 24),
#  ('something', 23),
#  ('going', 22),
#  ('take', 22),
#  ('maybe', 22),
#  ('sorry', 22),
#  ('friend', 21),
#  ('tell', 21),
#  ('please', 21),
#  ('need', 21),
#  ('u', 20),
#  ('thing', 20),
#  ('party', 20),
#  ('alex', 19),
#  ('college', 19),
#  ('talk', 18),
#  ('totally', 18),
#  ('make', 18),
#  ('love', 17),
#  ('school', 17),
#  ('stop', 16),
# ...

# %%
alex_count = (word for word in b['alex'])
alex_words = Counter(alex_count)
alex_words.most_common(200)
# Out:
# [('mom', 77),
#  ('oh', 64),
#  ('know', 52),
#  ('dad', 49),
#  ('like', 49),
#  ('okay', 41),
#  ('get', 39),
#  ('family', 38),
#  ('want', 38),
#  ('one', 35),
#  ('go', 32),
#  ('haley', 30),
#  ('modern', 30),
#  ('really', 29),
#  ('got', 28),
#  ('season', 28),
#  ('god', 28),
#  ('think', 28),
#  ('yeah', 27),
#  ('hey', 25),
#  ('luke', 24),
#  ('gon', 23),
#  ('good', 23),
#  ('never', 21),
#  ('going', 20),
#  ('even', 19),
#  ('ca', 19),
#  ('time', 19),
#  ('say', 18),
#  ('need', 18),
#  ('look', 18),
#  ('doe', 18),
#  ('right', 18),
#  ('would', 17),
#  ('mean', 17),
#  ('guy', 17),
#  ('take', 17),
#  ('coming', 17),
#  ('come', 16),
#  ('grandpa', 16),
#  ('u', 16),
#  ('let', 15),
#  ('well', 15),
#  ('ha', 14),
#  ('school', 13),
#  ('friend', 13),
#  ('thing', 13),
#  ('boy', 13),
#  ('way', 13),
#  ('please', 13),
#  ('day', 13),
#  ('car', 13),
#  ('ever', 12),
#  ('tell', 12),
#  ('trying', 12),
#  ('stop', 12),
#  ('see', 11),
#  ('love', 11),
# ...

# %%
gloria_count = (word for word in b['gloria'])
gloria_words = Counter(gloria_count)
gloria_words.most_common(200)
# Out:
# [('jay', 225),
#  ('manny', 179),
#  ('like', 164),
#  ('go', 154),
#  ('ay', 153),
#  ('know', 151),
#  ('okay', 132),
#  ('want', 110),
#  ('one', 93),
#  ('oh', 88),
#  ('gon', 87),
#  ('going', 85),
#  ('get', 83),
#  ('think', 82),
#  ('family', 81),
#  ('little', 75),
#  ('look', 74),
#  ('come', 71),
#  ('say', 70),
#  ('see', 66),
#  ('time', 66),
#  ('yes', 59),
#  ('good', 59),
#  ('need', 58),
#  ('make', 56),
#  ('thing', 54),
#  ('yeah', 53),
#  ('take', 47),
#  ('would', 46),
#  ('modern', 43),
#  ('love', 42),
#  ('let', 42),
#  ('day', 42),
#  ('season', 42),
#  ('tell', 41),
#  ('ha', 38),
#  ('right', 38),
#  ('sorry', 37),
#  ('something', 36),
#  ('back', 36),
#  ('maybe', 36),
#  ('ca', 36),
#  ('doe', 35),
#  ('even', 34),
#  ('people', 34),
#  ('dog', 34),
#  ('never', 33),
#  ('beautiful', 32),
#  ('first', 32),
#  ('really', 32),
#  ('claire', 32),
#  ('talk', 31),
#  ('baby', 31),
#  ('said', 31),
#  ('stop', 30),
#  ('fine', 30),
#  ('phil', 29),
# ...

# %%
jay_count = (word for word in b['jay'])
jay_words = Counter(jay_count)
jay_words.most_common(200)
# Out:
# [('know', 253),
#  ('got', 206),
#  ('get', 197),
#  ('like', 179),
#  ('go', 175),
#  ('oh', 163),
#  ('right', 158),
#  ('gloria', 139),
#  ('gon', 133),
#  ('kid', 122),
#  ('let', 119),
#  ('one', 119),
#  ('want', 119),
#  ('thing', 116),
#  ('little', 111),
#  ('guy', 107),
#  ('come', 103),
#  ('manny', 99),
#  ('yeah', 99),
#  ('well', 97),
#  ('look', 96),
#  ('hey', 92),
#  ('family', 91),
#  ('think', 90),
#  ('okay', 90),
#  ('time', 89),
#  ('see', 89),
#  ('say', 83),
#  ('good', 83),
#  ('could', 72),
#  ('tell', 71),
#  ('would', 71),
#  ('modern', 64),
#  ('season', 63),
#  ('take', 62),
#  ('mean', 62),
#  ('never', 62),
#  ('ca', 60),
#  ('make', 56),
#  ('hell', 56),
#  ('uh', 54),
#  ('something', 51),
#  ('need', 50),
#  ('day', 50),
#  ('love', 49),
#  ('sorry', 48),
#  ('really', 46),
#  ('going', 46),
#  ('wait', 45),
#  ('give', 44),
#  ('way', 44),
#  ('back', 43),
#  ('people', 43),
#  ('doe', 43),
#  ('said', 42),
#  ('fine', 41),
#  ('first', 40),
# ...

# %%
manny_count = (word for word in b['manny'])
manny_words = Counter(manny_count)
manny_words.most_common(200)
# Out:
# [('mom', 79),
#  ('jay', 78),
#  ('like', 68),
#  ('know', 65),
#  ('okay', 49),
#  ('oh', 44),
#  ('get', 44),
#  ('go', 43),
#  ('think', 43),
#  ('well', 42),
#  ('one', 39),
#  ('going', 39),
#  ('want', 36),
#  ('mean', 33),
#  ('say', 32),
#  ('ca', 31),
#  ('got', 31),
#  ('maybe', 29),
#  ('family', 29),
#  ('hey', 29),
#  ('would', 28),
#  ('gon', 27),
#  ('good', 27),
#  ('time', 26),
#  ('look', 26),
#  ('let', 26),
#  ('thing', 25),
#  ('yeah', 25),
#  ('said', 24),
#  ('something', 24),
#  ('guy', 24),
#  ('really', 23),
#  ('right', 23),
#  ('make', 23),
#  ('modern', 23),
#  ('could', 21),
#  ('season', 21),
#  ('love', 20),
#  ('come', 20),
#  ('first', 19),
#  ('never', 19),
#  ('thought', 18),
#  ('doe', 18),
#  ('great', 18),
#  ('luke', 18),
#  ('sorry', 18),
#  ('sure', 18),
#  ('little', 18),
#  ('see', 18),
#  ('tell', 17),
#  ('take', 17),
#  ('stop', 17),
#  ('back', 17),
#  ('girl', 16),
#  ('need', 16),
#  ('kid', 16),
#  ('today', 16),
#  ('u', 16),
# ...

# %%
mitch_count = (word for word in b['mitch'])
mitch_words = Counter(mitch_count)
mitch_words.most_common(200)
# Out:
# [('oh', 451),
#  ('okay', 367),
#  ('know', 323),
#  ('cam', 290),
#  ('well', 214),
#  ('yeah', 201),
#  ('right', 171),
#  ('like', 163),
#  ('get', 143),
#  ('gon', 134),
#  ('lily', 128),
#  ('really', 124),
#  ('one', 124),
#  ('yes', 123),
#  ('dad', 119),
#  ('uh', 119),
#  ('think', 117),
#  ('go', 107),
#  ('got', 105),
#  ('come', 103),
#  ('hey', 103),
#  ('family', 100),
#  ('god', 97),
#  ('little', 96),
#  ('want', 94),
#  ('u', 89),
#  ('sorry', 85),
#  ('modern', 85),
#  ('would', 81),
#  ('look', 81),
#  ('good', 79),
#  ('season', 79),
#  ('time', 78),
#  ('say', 78),
#  ('could', 73),
#  ('thank', 71),
#  ('thing', 69),
#  ('let', 69),
#  ('need', 68),
#  ('um', 68),
#  ('i-i', 67),
#  ('ca', 65),
#  ('see', 65),
#  ('stop', 64),
#  ('going', 60),
#  ('mean', 59),
#  ('take', 58),
#  ('wait', 58),
#  ('back', 56),
#  ('doe', 53),
#  ('never', 53),
#  ('make', 52),
#  ('hi', 49),
#  ('baby', 49),
#  ('maybe', 48),
#  ('something', 48),
#  ('great', 48),
# ...

# %%
cam_count = (word for word in b['cam'])
cam_words = Counter(cam_count)
cam_words.most_common(200)
# Out:
# [('oh', 475),
#  ('know', 326),
#  ('okay', 218),
#  ('well', 211),
#  ('mitchell', 173),
#  ('go', 164),
#  ('like', 161),
#  ('get', 155),
#  ('yeah', 147),
#  ('gon', 139),
#  ('think', 127),
#  ('would', 126),
#  ('one', 124),
#  ('lily', 124),
#  ('family', 113),
#  ('right', 113),
#  ('let', 102),
#  ('modern', 90),
#  ('season', 88),
#  ('want', 87),
#  ('little', 85),
#  ('come', 82),
#  ('yes', 81),
#  ('could', 81),
#  ('hey', 75),
#  ('really', 74),
#  ('got', 73),
#  ('time', 73),
#  ('look', 73),
#  ('say', 72),
#  ('good', 72),
#  ('love', 70),
#  ('thing', 69),
#  ('need', 69),
#  ('mean', 67),
#  ('sorry', 65),
#  ('u', 65),
#  ('back', 64),
#  ('ca', 62),
#  ('uh', 60),
#  ('make', 59),
#  ('people', 58),
#  ('maybe', 55),
#  ('see', 52),
#  ('jay', 52),
#  ('god', 50),
#  ('something', 49),
#  ('take', 48),
#  ('great', 48),
#  ('thank', 47),
#  ('way', 47),
#  ('doe', 45),
#  ('baby', 44),
#  ('said', 44),
#  ('going', 43),
#  ('tell', 42),
#  ('two', 42),
# ...

# %%
lily_count = (word for word in b['lily'])
lily_words = Counter(lily_count)
lily_words.most_common(200)
# Out:
# [('daddy', 25),
#  ('want', 8),
#  ('like', 6),
#  ('ca', 6),
#  ('oh', 6),
#  ('bunny', 6),
#  ('go', 5),
#  ('come', 5),
#  ('wait', 5),
#  ('modern', 4),
#  ('family', 4),
#  ('good', 4),
#  ('yes', 4),
#  ('time', 3),
#  ('really', 3),
#  ('three', 3),
#  ('get', 3),
#  ('home', 3),
#  ('shoe', 3),
#  ('doe', 3),
#  ('going', 3),
#  ('turkey', 3),
#  ('honey', 3),
#  ('ever', 3),
#  ('larry', 3),
#  ('season5', 3),
#  ('know', 3),
#  ('mommy', 2),
#  ('night', 2),
#  ('boy', 2),
#  ('hate', 2),
#  ('baby', 2),
#  ('matchy', 2),
#  ('new', 2),
#  ('gon', 2),
#  ('box', 2),
#  ('pretty', 2),
#  ('love', 2),
#  ('fruit', 2),
#  ('wan', 2),
#  ('watch', 2),
#  ('maybe', 2),
#  ('gloria', 2),
#  ('yay', 2),
#  ('jacket', 2),
#  ('aah', 2),
#  ('ha', 2),
#  ('okay', 2),
#  ('need', 2),
#  ('dance', 2),
#  ('bathroom', 2),
#  ('hair', 2),
#  ('ew', 2),
#  ('back', 2),
#  ('one', 2),
#  ('fall', 2),
#  ('got', 2),
#  ('little', 2),
#  ('haley', 2),
#  ('see', 2),
#  ('seen', 2),
# ...
